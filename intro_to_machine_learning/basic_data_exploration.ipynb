# %% [markdown]
# <a href="https://colab.research.google.com/github/kaveenseneviratne/kaggle-learn/blob/main/intro_to_machine_learning/basic_data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
